# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

stock = "BBRI.JK"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2025, 12, 1)

df = yf.download(stock, start, end)
# Out:
# /tmp/ipython-input-1490211032.py:8: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price           Close       High        Low       Open      Volume
# Ticker        BBRI.JK    BBRI.JK    BBRI.JK    BBRI.JK     BBRI.JK
# Date
# 2003-11-10  38.552673  43.495324  37.564142  41.518263  5658651738
# 2003-11-11  39.541195  39.541195  37.564137  38.552668  3232466332
# 2003-11-12  41.518261  41.518261  38.552672  38.552672  2203244555
# 2003-11-13  41.518261  41.518261  40.529730  41.518261  1309077610
# 2003-11-14  41.518261  41.518261  39.541199  41.518261  1897824280

# %%
df.tail()
# Out:
# Price             Close         High          Low         Open     Volume
# Ticker          BBRI.JK      BBRI.JK      BBRI.JK      BBRI.JK    BBRI.JK
# Date
# 2025-11-24  3835.751465  3855.026598  3797.201199  3855.026598  262302000
# 2025-11-25  3691.187744  3835.751233  3691.187744  3835.751233  396959100
# 2025-11-26  3652.637695  3691.187961  3643.000129  3662.275262  288419400
# 2025-11-27  3604.449707  3671.912669  3585.174575  3662.275103  283451800
# 2025-11-28  3546.624268  3614.087229  3546.624268  3575.536965  353872800

# %%
df.shape
# Out:
# (5453, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5453 entries, 2003-11-10 to 2025-11-28
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, BBRI.JK)   5453 non-null   float64
#  1   (High, BBRI.JK)    5453 non-null   float64
#  2   (Low, BBRI.JK)     5453 non-null   float64
#  3   (Open, BBRI.JK)    5453 non-null   float64
#  4   (Volume, BBRI.JK)  5453 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 255.6 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   BBRI.JK    0
# High    BBRI.JK    0
# Low     BBRI.JK    0
# Open    BBRI.JK    0
# Volume  BBRI.JK    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker      BBRI.JK      BBRI.JK      BBRI.JK      BBRI.JK       BBRI.JK
# count   5453.000000  5453.000000  5453.000000  5453.000000  5.453000e+03
# mean    1573.387520  1591.939508  1555.696798  1574.396155  1.785372e+08
# std     1393.856664  1409.133930  1380.667844  1395.202094  1.588757e+08
# min       38.552673    39.541195    37.564137    38.552668  0.000000e+00
# 25%      341.049103   347.347028   335.612437   341.049103  9.737038e+07
# 50%     1179.126953  1196.503826  1163.035414  1176.980713  1.431679e+08
# 75%     2671.437988  2705.863623  2643.897513  2672.356116  2.181621e+08
# max     5554.226074  5576.266760  5488.104439  5554.226180  5.658652e+09

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',        ''),
#             ( 'Close', 'BBRI.JK'),
#             (  'High', 'BBRI.JK'),
#             (   'Low', 'BBRI.JK'),
#             (  'Open', 'BBRI.JK'),
#             ('Volume', 'BBRI.JK')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv('BBRI.JK.csv')

# %%
data01 = pd.read_csv('BBRI.JK.csv')

# %%
data01.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN             BBRI.JK             BBRI.JK
# 1       0  2003-11-10   38.55267333984375   43.49532427856532
# 2       1  2003-11-11  39.541194915771484  39.541194915771484
# 3       2  2003-11-12   41.51826095581055   41.51826095581055
# 4       3  2003-11-13   41.51826095581055   41.51826095581055
#
#                   Low                Open      Volume
# 0             BBRI.JK             BBRI.JK     BBRI.JK
# 1   37.56414248840201  41.518262575681845  5658651738
# 2  37.564136829226214   38.55266753174215  3232466332
# 3    38.5526718356775    38.5526718356775  2203244555
# 4  40.529730142937204   41.51826095581055  1309077610

# %%
#Candlesticks
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'],
                                     high = data01['High'], low = data01['Low'],
                                     close = data01['Close'] )])

fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
# Price        Date      Close       High        Low       Open      Volume
# Ticker               BBRI.JK    BBRI.JK    BBRI.JK    BBRI.JK     BBRI.JK
# 0      2003-11-10  38.552673  43.495324  37.564142  41.518263  5658651738
# 1      2003-11-11  39.541195  39.541195  37.564137  38.552668  3232466332
# 2      2003-11-12  41.518261  41.518261  38.552672  38.552672  2203244555
# 3      2003-11-13  41.518261  41.518261  40.529730  41.518261  1309077610
# 4      2003-11-14  41.518261  41.518261  39.541199  41.518261  1897824280

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Open"], label = f"{stock} Opening Price", linewidth = 1)
plt.title(f"{stock} Open Price over time")
plt.xlabel("Date")
plt.ylabel("Closing Price (Rupiah)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Close"], label = f"{stock} Closing Price", linewidth = 1)
plt.title(f"{stock} Closing Price over time")
plt.legend()
plt.show()

# %%
#Moving Average
# [10, 20, 30 , 40, 50, 60, 70, 80, 90]
# Moving Average for last 5 days -> (10+20+30+40+50)/5 = 30

temp_data = [10, 20, 30 , 40, 50, 60, 70, 80, 90]
print(sum(temp_data[0:5])/5)
print(sum(temp_data[1:6])/5)
# Out:
# 30.0
# 40.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker      BBRI.JK
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 5448    3763.084099
# 5449    3764.626108
# 5450    3765.493491
# 5451    3766.168120
# 5452    3766.168120
#
# [5453 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f"{stock} Closing Price", linewidth = 1)
plt.plot(ma100, label = f"{stock} Moving Average 100", linewidth = 1)
plt.plot(ma200, label = f"{stock} Moving Average 200", linewidth = 1)
plt.title(f"{stock} Closing Price over time")
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean()

# %%
ema200 = df.Close.ewm(span=200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f"{stock} Closing Price", linewidth = 1)
plt.plot(ema100, label = f"{stock} EXP Moving Average 100", linewidth = 1)
plt.plot(ema200, label = f"{stock} EXP Moving Average 200", linewidth = 1)
plt.title(f"{stock} Closing Price over time")
plt.legend()
plt.show()

# %%
df.pct_change
# Out:
# <bound method NDFrame.pct_change of Price        Date        Close         High          Low         Open  \
# Ticker                 BBRI.JK      BBRI.JK      BBRI.JK      BBRI.JK
# 0      2003-11-10    38.552673    43.495324    37.564142    41.518263
# 1      2003-11-11    39.541195    39.541195    37.564137    38.552668
# 2      2003-11-12    41.518261    41.518261    38.552672    38.552672
# 3      2003-11-13    41.518261    41.518261    40.529730    41.518261
# 4      2003-11-14    41.518261    41.518261    39.541199    41.518261
# ...           ...          ...          ...          ...          ...
# 5448   2025-11-24  3835.751465  3855.026598  3797.201199  3855.026598
# 5449   2025-11-25  3691.187744  3835.751233  3691.187744  3835.751233
# 5450   2025-11-26  3652.637695  3691.187961  3643.000129  3662.275262
# 5451   2025-11-27  3604.449707  3671.912669  3585.174575  3662.275103
# 5452   2025-11-28  3546.624268  3614.087229  3546.624268  3575.536965
#
# Price       Volume
# ...

# %%
# To avoid the TypeError, we need to exclude the 'Date' column from the pct_change calculation.
# The 'Date' column is currently represented as ('Date', '') in the MultiIndex columns.
# We will create a new DataFrame without the 'Date' column to apply pct_change.
df.pct_change = df.drop(columns=[('Date', '')])

# %%
df.pct_change
# Out:
# Price         Close         High          Low         Open      Volume
# Ticker      BBRI.JK      BBRI.JK      BBRI.JK      BBRI.JK     BBRI.JK
# 0         38.552673    43.495324    37.564142    41.518263  5658651738
# 1         39.541195    39.541195    37.564137    38.552668  3232466332
# 2         41.518261    41.518261    38.552672    38.552672  2203244555
# 3         41.518261    41.518261    40.529730    41.518261  1309077610
# 4         41.518261    41.518261    39.541199    41.518261  1897824280
# ...             ...          ...          ...          ...         ...
# 5448    3835.751465  3855.026598  3797.201199  3855.026598   262302000
# 5449    3691.187744  3835.751233  3691.187744  3835.751233   396959100
# 5450    3652.637695  3691.187961  3643.000129  3662.275262   288419400
# 5451    3604.449707  3671.912669  3585.174575  3662.275103   283451800
# 5452    3546.624268  3614.087229  3546.624268  3575.536965   353872800
#
# [5453 rows x 5 columns]

# %%
df.columns
# Out:
# MultiIndex([(  'Date',        ''),
#             ( 'Close', 'BBRI.JK'),
#             (  'High', 'BBRI.JK'),
#             (   'Low', 'BBRI.JK'),
#             (  'Open', 'BBRI.JK'),
#             ('Volume', 'BBRI.JK')],
#            names=['Price', 'Ticker'])

# %%
# Training and Testing
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (3817, 1)

# %%
data_testing.shape
# Out:
# (1636, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.00000000e+00],
#        [4.05824600e-04],
#        [1.21748320e-03],
#        ...,
#        [9.84608674e-01],
#        [9.84608674e-01],
#        [9.71782503e-01]])

# %%
data_training_array.shape[0]
# Out:
# 3817

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
  x_train.append(data_training_array[i-100: i])
  y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (3717, 100, 1)

# %%
y_train.shape
# Out:
# (3717,)

# %%
# Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %% [markdown]
# LSTM input -> 3D Array (batch_size, time steps, seq len)
#
# ...

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 39s 253ms/step - loss: 0.0512
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 21s 178ms/step - loss: 0.0055
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 21s 179ms/step - loss: 0.0043
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 40s 172ms/step - loss: 0.0049
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 21s 178ms/step - loss: 0.0042
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 172ms/step - loss: 0.0046
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - loss: 0.0037
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - loss: 0.0045
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - loss: 0.0036
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 173ms/step - loss: 0.0039
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - loss: 0.0037
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 171ms/step - loss: 0.0037
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 166ms/step - loss: 0.0034
# Epoch 14/50
# ...

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
# Ticker      BBRI.JK
# 0       1905.777954
# 1       1887.032959
# 2       1843.293701
# 3       1874.536133
# 4       1868.287476

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
  x_test.append(input_data[i-100: i])
  y_test.append(input_data[i, 0])

x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1636, 100, 1)

# %%
y_test.shape
# Out:
# (1636,)

# %%
y_predicted = model.predict(x_test)
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step

# %%
y_predicted.shape
# Out:
# (1636, 1)

# %%
scaler.scale_
# Out:
# array([0.00024418])

# %%
scaler_factor = 1 / 0.00024418
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.keras')
